# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
def extract_values_with_fallback(csv_file, col_name, target_column, primary_value):
    # Read the CSV file
    df = pd.read_csv(csv_file)
    
    # Try finding rows where col_name matches primary_value
    filtered_values = df.loc[df[col_name].isin(primary_value), target_column]
    
    # Convert the result to a NumPy array
    result_array = filtered_values.to_numpy()
    
    return result_array

# %%
#Note: for  this to work, you should have all the csv files with the same names inside the same directory as this notebook
files = ['./data1_H9.csv','./data2_H2.csv','./data3_H7.csv','./data4_H6.csv','./data5_H8.csv','./data6_H8.csv','./data7_H4.csv','./data8_H5.csv','./data9_H2.csv','./data10_H2.csv','./data11_H1.csv','./data12_H2.csv','./data13_H1.csv','./data14_H1.csv', './data15_H1.csv', './data16_H1.csv', './data17_H1.csv', './data18_H1.csv']
col_name = "mouse_click"               # target column name
target_column = "stim"       # column whose values we want to extract

# %%
result_liked =[]

for i in range(len(files)):
    ans = extract_values_with_fallback(files[i],col_name,target_column,["Very_Good","Good"])
    #print("ID:", i+1)
    #print(ans)
    result_liked.append(ans)

flattened_array = [item for sublist in result_liked for item in sublist]  
    
    # Count occurrences of each value
counts = Counter(flattened_array)

top_10_foods = counts.most_common(10)
food_names, frequencies = zip(*top_10_foods)

import pandas as pd
data = pd.DataFrame({"Food": food_names, "Frequency": frequencies})

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    data=data,
    y="Food",
    x="Frequency",
    palette="viridis"
)

# Add labels and title
plt.title("Top 10 Most Liked Foods", fontsize=16)
plt.xlabel("Frequency", fontsize=12)
plt.ylabel("Food Names", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
    
    # Find the maximum frequency
max_count = max(counts.values())
    
    # Find all values with the maximum frequency
most_frequent = {key: value for key, value in counts.items() if value == max_count}
    
print("Most Liked:",most_frequent)
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_6388\3379799003.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Most Liked: {'ChipsAhoy': 16, 'KitKat': 16}

# %%
result_disliked = []

for i in range(len(files)):
    ans = extract_values_with_fallback(files[i],col_name,target_column,["Very_Bad","Bad"])
    #print("ID:", i+1)
    #print(ans)
    result_disliked.append(ans)

flattened_array_unliked = [item for sublist in result_disliked for item in sublist]  
    
    # Count occurrences of each value
counts_unliked = Counter(flattened_array_unliked)

top_10_foods = counts_unliked.most_common(10)
food_names, frequencies = zip(*top_10_foods)

import pandas as pd
data = pd.DataFrame({"Food": food_names, "Frequency": frequencies})

# Plot the horizontal bar chart
plt.figure(figsize=(10, 6))
sns.barplot(
    data=data,
    y="Food",
    x="Frequency",
    palette="viridis"
)

# Add labels and title
plt.title("Top 10 Most Disliked Foods", fontsize=16)
plt.xlabel("Frequency", fontsize=12)
plt.ylabel("Food Names", fontsize=12)
plt.grid(axis="x", linestyle="--", alpha=0.7)

# Show the plot
plt.tight_layout()
plt.show()
    
    # Find the maximum frequency
max_count_unliked = max(counts_unliked.values())
    
    # Find all values with the maximum frequency
most_frequent_unliked = {key: value for key, value in counts_unliked.items() if value == max_count_unliked}
    
print("Most Disliked: ",most_frequent_unliked)
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_6388\608053156.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# Most Disliked:  {'brocollincauliflower': 8, 'wheatcrisps': 8}
